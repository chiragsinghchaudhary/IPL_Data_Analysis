# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dl = pd.read_csv(r'E:\D S\4A D S\ML by k\Dataset\deliveries.csv')

# %%
dl
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 164745      7953       2  Chennai Super Kings          Sunrisers Hyderabad
# 164746      7953       2  Chennai Super Kings          Sunrisers Hyderabad
# 164747      7953       2  Chennai Super Kings          Sunrisers Hyderabad
# 164748      7953       2  Chennai Super Kings          Sunrisers Hyderabad
# 164749      7953       2  Chennai Super Kings          Sunrisers Hyderabad
#
# ...

# %%
dl.isnull().sum
# Out:
# <bound method DataFrame.sum of         match_id  inning  batting_team  bowling_team   over   ball  batsman  \
# 0          False   False         False         False  False  False    False
# 1          False   False         False         False  False  False    False
# 2          False   False         False         False  False  False    False
# 3          False   False         False         False  False  False    False
# 4          False   False         False         False  False  False    False
# ...          ...     ...           ...           ...    ...    ...      ...
# 164745     False   False         False         False  False  False    False
# 164746     False   False         False         False  False  False    False
# 164747     False   False         False         False  False  False    False
# 164748     False   False         False         False  False  False    False
# 164749     False   False         False         False  False  False    False
#
# ...

# %%
M1=dl.loc[dl['match_id']==1]

# %%
I1=M1.loc[M1['inning']==1]

# %%
batsman=I1['batsman'].unique()

# %%
brun=I1.groupby('batsman')['batsman_runs'].sum()

# %%
ballrecived=I1.groupby('batsman')['ball'].count()

# %%
brun
# Out:
# batsman
# BCJ Cutting     16
# DA Warner       14
# DJ Hooda        16
# MC Henriques    52
# S Dhawan        40
# Yuvraj Singh    62
# Name: batsman_runs, dtype: int64

# %%
I1
# Out:
#      match_id  inning         batting_team                 bowling_team  over  \
# 0           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# ..        ...     ...                  ...                          ...   ...
# 120         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    20
# 121         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    20
# 122         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    20
# 123         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    20
# 124         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    20
#
# ...

# %%
extras=I1.loc[I1['extra_runs']>=1].index

# %%
I1.loc[I1['over']==1]
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# ...

# %%
score_card=pd.merge(brun,ballrecived,on='batsman')

# %%
score_card
# Out:
#               batsman_runs  ball
# batsman
# BCJ Cutting             16     6
# DA Warner               14     9
# DJ Hooda                16    12
# MC Henriques            52    37
# S Dhawan                40    31
# Yuvraj Singh            62    30

# %%
I1.drop(index=extras,inplace=True)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
I1
# Out:
#      match_id  inning         batting_team                 bowling_team  over  \
# 0           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# ..        ...     ...                  ...                          ...   ...
# 120         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    20
# 121         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    20
# 122         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    20
# 123         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    20
# 124         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    20
#
# ...

# %%
score_card
# Out:
#               batsman_runs  ball
# batsman
# BCJ Cutting             16     6
# DA Warner               14     9
# DJ Hooda                16    12
# MC Henriques            52    37
# S Dhawan                40    31
# Yuvraj Singh            62    30

# %%
def run4(a):
    if a ==4:
        return a.count()

# %%
a=I1.loc[I1['total_runs']==4]

# %%
four=a.groupby('batsman')['total_runs'].count()

# %%
four
# Out:
# batsman
# DA Warner       2
# MC Henriques    3
# S Dhawan        5
# Yuvraj Singh    7
# Name: total_runs, dtype: int64

# %%
score_card=pd.merge(score_card,four,on='batsman',how='right')

# %%
score_card
# Out:
#               batsman_runs  ball  total_runs
# batsman
# DA Warner               14     9           2
# MC Henriques            52    37           3
# S Dhawan                40    31           5
# Yuvraj Singh            62    30           7

# %%
t_r=I1.loc[I1['total_runs']==6]

# %%
six=t_r.groupby('batsman')['total_runs'].count()

# %%
six
# Out:
# batsman
# BCJ Cutting     2
# DA Warner       1
# DJ Hooda        1
# MC Henriques    2
# Yuvraj Singh    3
# Name: total_runs, dtype: int64

# %%
dd2=pd.merge(six,score_card,on='batsman',how='right')

# %%
dd2
# Out:
#               total_runs  batsman_runs  ball
# batsman
# BCJ Cutting          2.0            16     6
# DA Warner            1.0            14     9
# DJ Hooda             1.0            16    12
# MC Henriques         2.0            52    37
# Yuvraj Singh         3.0            62    30
# S Dhawan             NaN            40    31

# %%
score_card.rename(columns={'batsman':'Batsman','batsman_runs_x':'Batsman_runs','ball_x':'Balls','total_runs_x':'Fours','total_runs_y':'Sixes'},inplace=True)

# %%
score_card
# Out:
#               batsman_runs  ball
# batsman
# BCJ Cutting             16     6
# DA Warner               14     9
# DJ Hooda                16    12
# MC Henriques            52    37
# S Dhawan                40    31
# Yuvraj Singh            62    30

# %%
score_card.reset_index(inplace=True)

# %%
score_card.fillna(value=0,inplace=True)

# %%
score_card
# Out:
#         batsman  batsman_runs  ball
# 0   BCJ Cutting            16     6
# 1     DA Warner            14     9
# 2      DJ Hooda            16    12
# 3  MC Henriques            52    37
# 4      S Dhawan            40    31
# 5  Yuvraj Singh            62    30

# %%
score_card['Fours']=score_card['Fours'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Fours'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-167-b7178d3b5e24> in <module>
# ...

# %%
score_card['Sixes']=score_card['Sixes'].astype('int')

# %%
score_card
# Out:
#         batsman  Fours  batsman_runs  ball  Sixes
# 0     DA Warner      1            14     9      2
# 1  MC Henriques      2            52    37      3
# 2  Yuvraj Singh      3            62    30      7
# 3      S Dhawan      0            40    31      5

# %%
score_card['SR']=score_card['batsman_runs']/score_card['ball']*100

# %%
score_card
# Out:
#         batsman  Fours  batsman_runs  ball  Sixes          SR
# 0     DA Warner      1            14     9      2  155.555556
# 1  MC Henriques      2            52    37      3  140.540541
# 2  Yuvraj Singh      3            62    30      7  206.666667
# 3      S Dhawan      0            40    31      5  129.032258

# %%
score_card['SR']=score_card['SR'].round()

# %%
score_card
# Out:
#         batsman  Fours  batsman_runs  ball  Sixes     SR
# 0     DA Warner      1            14     9      2  156.0
# 1  MC Henriques      2            52    37      3  141.0
# 2  Yuvraj Singh      3            62    30      7  207.0
# 3      S Dhawan      0            40    31      5  129.0

# %%
column=['Batsman','Batsman_runs','Balls','Fours','Sixes','SR']

# %%
score_card=score_card.reindex(columns=column)

# %%
score_card
# Out:
#    Batsman  Batsman_runs  Balls  Fours  Sixes     SR
# 0      NaN           NaN    NaN      1      2  156.0
# 1      NaN           NaN    NaN      2      3  141.0
# 2      NaN           NaN    NaN      3      7  207.0
# 3      NaN           NaN    NaN      0      5  129.0

# %%
l=I1.groupby('batsman')['ball'].count()

# %%
score_card
# Out:
#    Batsman  Batsman_runs  Balls  Fours  Sixes     SR
# 0      NaN           NaN    NaN      1      2  156.0
# 1      NaN           NaN    NaN      2      3  141.0
# 2      NaN           NaN    NaN      3      7  207.0
# 3      NaN           NaN    NaN      0      5  129.0

# %%
i=l.reset_index()

# %%
i
# Out:
#    index       batsman  ball
# 0      0   BCJ Cutting     6
# 1      1     DA Warner     7
# 2      2      DJ Hooda    12
# 3      3  MC Henriques    37
# 4      4      S Dhawan    30
# 5      5  Yuvraj Singh    27

# %%
i.rename(columns={'batsman':'Batsman'},inplace=True)

# %%
i
# Out:
#    index       Batsman  ball
# 0      0   BCJ Cutting     6
# 1      1     DA Warner     7
# 2      2      DJ Hooda    12
# 3      3  MC Henriques    37
# 4      4      S Dhawan    30
# 5      5  Yuvraj Singh    27

# %%
SC=pd.concat(score_card,i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-01b95b8e042a> in <module>
# ----> 1 SC=pd.concat(score_card,i)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     253         verify_integrity=verify_integrity,
#     254         copy=copy,
# --> 255         sort=sort,
#     256     )
#     257
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     282                 "first argument must be an iterable of pandas "
#     283                 "objects, you passed an object of type "
# --> 284                 '"{name}"'.format(name=type(objs).__name__)
#     285             )
#     286
#
# ...

# %%
e=pd.merge(score_card,l,left_on=None)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-108-56e493b28b57> in <module>
# ----> 1 e=pd.merge(score_card,l,left_on=None)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     617             warnings.warn(msg, UserWarning)
#     618
# --> 619         self._validate_specification()
#     620
#     621         # note this function has side effects
#
# ...

# %%
def run4(a):
    if a ==4:
        return a.count()

# %%
a=I1.loc[I1['total_runs']==4]

# %%
e=pd.merge(c,dl,on='batsman',how='left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-316ac28319e3> in <module>
# ----> 1 e=pd.merge(c,dl,on='batsman',how='left')
#
# NameError: name 'c' is not defined

# %%
a
# Out:
#      match_id  inning         batting_team                 bowling_team  over  \
# 2           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 8           1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 13          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 30          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     5
# 32          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     6
# 33          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     6
# 35          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     6
# 36          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     6
# 63          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    11
# 72          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    12
# 74          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    13
# ...

# %%
four=a.groupby('batsman')['total_runs'].count()

# %%
four
# Out:
# batsman
# DA Warner       2
# MC Henriques    3
# S Dhawan        5
# Yuvraj Singh    7
# Name: total_runs, dtype: int64

# %%
b=I1.loc[I1['total_runs']==6]

# %%
six=b.groupby('batsman')['total_runs'].count()

# %%
score_card=pd.merge(score_card,four,on='batsman',how='left')

# %%
score_card
# Out:
#               total_runs_x  batsman_runs  ball  total_runs_y  total_runs
# batsman
# BCJ Cutting            2.0            16     6           NaN         NaN
# DA Warner              1.0            14     9           2.0         2.0
# DJ Hooda               1.0            16    12           NaN         NaN
# MC Henriques           2.0            52    37           3.0         3.0
# Yuvraj Singh           3.0            62    30           7.0         7.0
# S Dhawan               NaN            40    31           5.0         5.0

# %%
score_card=pd.merge(six,score_card,on='batsman',how='right')

# %%
score_card
# Out:
#               total_runs_x  total_runs_x  batsman_runs  ball  total_runs_y  \
# batsman
# BCJ Cutting            2.0           2.0            16     6           NaN
# DA Warner              1.0           1.0            14     9           2.0
# DJ Hooda               1.0           1.0            16    12           NaN
# MC Henriques           2.0           2.0            52    37           3.0
# Yuvraj Singh           3.0           3.0            62    30           7.0
# S Dhawan               NaN           NaN            40    31           5.0
#
#               total_runs_y
# batsman
# BCJ Cutting            NaN
# DA Warner              2.0
# DJ Hooda               NaN
# MC Henriques           3.0
# Yuvraj Singh           7.0
# S Dhawan               5.0

# %%
.rename(columns={'batsman':'Batsman','batsman_runs_x':'Batsman_runs','ball_x':'Balls','total_runs_x':'Fours','total_runs_y':'Sixes'},inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-240b307729f1> in <module>
# ----> 1 e.rename(columns={'batsman':'Batsman','batsman_runs_x':'Batsman_runs','ball_x':'Balls','total_runs_x':'Fours','total_runs_y':'Sixes'},inplace=True)
#
# NameError: name 'e' is not defined

# %%
score_card.fillna(value=0,inplace=True)

# %%
score_card
# Out:
#               total_runs_x  total_runs_x  batsman_runs  ball  total_runs_y  \
# batsman
# BCJ Cutting            2.0           2.0            16     6           0.0
# DA Warner              1.0           1.0            14     9           2.0
# DJ Hooda               1.0           1.0            16    12           0.0
# MC Henriques           2.0           2.0            52    37           3.0
# Yuvraj Singh           3.0           3.0            62    30           7.0
# S Dhawan               0.0           0.0            40    31           5.0
#
#               total_runs_y
# batsman
# BCJ Cutting            0.0
# DA Warner              2.0
# DJ Hooda               0.0
# MC Henriques           3.0
# Yuvraj Singh           7.0
# S Dhawan               5.0

# %%
score_card['SR']=score_card['Batsman_runs']/score_card['Balls']*100
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# KeyError: 'Batsman_runs'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-fd49987a7f08> in <module>
# ----> 1 score_card['SR']=score_card['Batsman_runs']/score_card['Balls']*100
# ...
